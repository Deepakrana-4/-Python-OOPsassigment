# %% [markdown]
# #PYTHON OOPs QUESTIONS
#
#  1.  What is Object-Oriented Programming (OOP)
#  >  OOP is a way of writing code where we think in terms of real-world things like:
#  CARS
#  DOG
#  We call these "objects" in programming.
# Each object has:
# 1-Data (what it has): like name, color, age
# 2-Behavior (what it does): like walk, talk, drive
#
#
#  2.  What is a class in OOP
# >> CLASS in oop is like a recipe or plan to make objects.
#
#  3.  What is an object in OOP
# >>an objet in oops is using the recipe (class), you create real cars.
#
#  4.  What is the difference between abstraction and encapsulation
#  >> Abstraction means hiding the extra details and showing only the useful part.
#  Encapsulation means hiding the data inside a class and only allowing access through methods (functions). It protects the data.
#
#  5.  What are dunder methods in Python
#  >>Dunder" means Double UNDerscore — so dunder methods are special methods in Python that start and end with two underscores
#  example __init__
#
#  6.  Explain the concept of inheritance in OOP
#  >> It’s like a child getting things from parents — name, habits, or skills.
# In code:
# 1-A parent class has some functions and variables.
# 2-A child class can use them without writing again.
#
#
#
#  7.  What is polymorphism in OOP
# >>In OOP, it means one function or method behaves differently based on the object.
#
#  8.  How is encapsulation achieved in Python
# >>1. By using private variables and methods
#
#
#   9.  What is a constructor in Python
# >>>  A constructor is a special function that automatically runs when you create an object from a class.
# In Python, the constructor is the __init__() method
#
#
# 10.   What are class and static methods in Python
# >>@classmethod
# A class method is a method that works with the class itself, not just the object.
# It takes cls as the first argument (instead of self)
# You can use it to change or access class-level data
#
# @staticmethod
# A static method is a method that doesn’t need the class (cls) or the object (self) at all.
# It’s just a regular function inside a class
# You use it when you don’t need to access object or class data
#
#
#  11.  What is method overloading in Python
# >>Method Overloading means having multiple methods with the same name but different parameters (like number, type, or order of arguments).
#
#
#
# 12.   What is method overriding in OOP
# >>Method Overriding means redefining a method in a child (derived) class that already exists in the parent (base) class.
#
#
#
#  13.  What is a property decorator in Python
# >>The @property decorator in Python is used to turn a method into a "getter" — meaning, it can be accessed like a variable without using parentheses.
#
#  14.  Why is polymorphism important in OOP
# >>1.Code Reusability and Flexibility
#   2.  Cleaner and More Readable Code
#   3. Easier to Maintain and Extend
#
#
#  15.  What is an abstract class in Python
# >>An abstract class is a class that:
# Cannot be instantiated on its own.
# Defines one or more abstract methods—methods without implementation—that must be implemented by any concrete (sub)class.
#
#  16.  What are the advantages of OOP
# >>> advantage of oop
#   1.Modularity
#   2.Reusability
#   3.  Polymorphism
#   4. Easy Maintenance & Upgrades
#   5. Real-world Mapping
#
#
#  17.  What is multiple inheritance in Python
# >>>Multiple Inheritance means a class inherits from more than one parent class.
# This allows a child class to combine features (methods/attributes) from multiple classes.
#
#  18.  What is the difference between a class variable and an instance variable
# >> Class Variable  1.	Class memory (shared across all instances)
#                    2.All instances of the class
#    Instance Variable  1.Object memory (separate for each instance)
#                       2.  Only that specific object (instance)
#
#  19.   Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python
# >>>__str__ Purpose: For end users
#   __repr__ Purpose: For debugging/developers
#
#
#  20.  What is the significance of the ‘super()’ function in Python
# >>The super() function is used to call methods from a parent (or superclass) inside a child class.
#
#
#  21. What is the significance of the __del__ method in Python
#   >>The __del__() method in Python is known as a destructor.
#
#  22.  What is the difference between @staticmethod and @classmethod in Python
# >>Both @staticmethod and @classmethod are decorators used to define non-regular methods inside a class — i.e., methods that don’t behave like normal instance methods (self).
#
#  23.How does polymorphism work in Python with inheritanc
#  >>Polymorphism means: same interface, different behavior.
# When combined with inheritance, it allows subclasses to provide their own version of a method defined in a parent class.
#
#
#
#  24.  What is method chaining in Python OOP
# >>>Method Chaining is a technique where multiple methods are called in a single line, one after the other, using dot (.) notation.
# Each method in the chain returns the object itself (self), allowing the next method to be called on it.
#
#  25.  What is the purpose of the __call__ method in Python?
#  >>The __call__() method in Python allows an object to be called like a function.

# %%
# 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".
class Animal: #parents class
    def speak(self):
        print("The animal makes a sound.")
class Dog(Animal):# child class
    def speak(self):
        print("Bark!")

# %%
 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
from it and implement the area() method in both
